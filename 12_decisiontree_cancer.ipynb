# %% [markdown]
# <a href="https://colab.research.google.com/github/Anandkajith/Data-Science-lab/blob/main/12_decisiontree_cancer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

#load dataset
df=pd.read_csv('/content/Cancer_DS.csv')

#first 5 row of dataset
print(df.head())

#columns of dataset
print(df.columns)

#check null value
print(df.isnull().sum())

#split of features and labels
x=df.drop(['id','diagnosis','Unnamed: 32'],axis=1)
y=df['diagnosis']

#train test splitting
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

#fitting decision tree
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
y_pre=dt.predict(x_test)

#checking accuracy
from sklearn.metrics import accuracy_score
ac=accuracy_score(y_pre,y_test)
print(ac)

#cheching sample data
a=[x_train.values[10]]
pre=dt.predict(a)
if pre[0]=='B':
    print("Benign")
else:
    print("Malignant")
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
from matplotlib import pyplot as plt
from sklearn import tree
fig = plt.figure(figsize=(25,20))
fig=tree.plot_tree(dt)
